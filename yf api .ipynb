# %%
# !pip install yfinance

# %%
import yfinance as yf

# %%
twii = yf.Ticker("^TWII")

# %%
twii.info
# Out:
# {'algorithm': None,
#  'ask': 0,
#  'askSize': 0,
#  'averageDailyVolume10Day': 3559620,
#  'averageVolume': 4086572,
#  'averageVolume10days': 3559620,
#  'beta': None,
#  'bid': 0,
#  'bidSize': 0,
#  'circulatingSupply': None,
#  'currency': 'TWD',
#  'dayHigh': 16345.84,
#  'dayLow': 16090.54,
#  'dividendRate': None,
#  'dividendYield': None,
#  'exDividendDate': None,
#  'exchange': 'TAI',
#  'exchangeTimezoneName': 'Asia/Taipei',
#  'exchangeTimezoneShortName': 'CST',
#  'expireDate': None,
#  'fiftyDayAverage': 17246.729,
#  'fiftyTwoWeekHigh': 18619.61,
#  'fiftyTwoWeekLow': 15159.86,
#  'fiveYearAvgDividendYield': None,
#  'forwardPE': None,
#  'fromCurrency': None,
#  'gmtOffSetMilliseconds': '28800000',
#  'isEsgPopulated': False,
#  'lastMarket': None,
#  'logo_url': '',
#  'market': 'tw_market',
#  'marketCap': None,
#  'maxAge': 1,
#  'maxSupply': None,
#  'messageBoardId': 'finmb_INDEXTWII',
#  'navPrice': None,
#  'open': 16345.84,
#  'openInterest': None,
# ...

# %%
twii.financials
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
print(twii.history().columns)
twii.history()
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')
#                     Open          High           Low         Close   Volume  \
# Date
# 2022-04-11  17273.050781  17316.349609  17046.669922  17048.369141  4584600
# 2022-04-12  17005.839844  17100.849609  16905.130859  16990.910156  4100800
# 2022-04-13  17080.400391  17333.210938  17080.400391  17301.650391  4058700
# 2022-04-14  17353.250000  17374.140625  17245.650391  17245.650391  4429600
# 2022-04-15  17139.339844  17141.330078  17004.179688  17004.179688  4078400
# 2022-04-18  16958.660156  16999.359375  16845.509766  16898.869141  4020900
# 2022-04-19  16926.339844  17106.259766  16926.339844  16993.400391  3514900
# 2022-04-20  17057.130859  17148.880859  16983.550781  17148.880859  4801300
# 2022-04-21  17159.880859  17213.660156  17106.369141  17127.949219  3952000
# 2022-04-22  17088.759766  17088.759766  16923.869141  17025.089844  4322500
# ...

# %%
yf.download("^TWII",period="7d",interval="1m")
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                    Open          High           Low  \
# Datetime
# 2022-04-28 09:00:00+08:00  16350.719727  16400.150391  16350.719727
# 2022-04-28 09:01:00+08:00  16397.179688  16397.179688  16375.990234
# 2022-04-28 09:02:00+08:00  16382.389648  16382.389648  16352.410156
# 2022-04-28 09:03:00+08:00  16364.250000  16364.250000  16353.750000
# 2022-04-28 09:04:00+08:00  16363.019531  16363.940430  16346.179688
# ...                                 ...           ...           ...
# 2022-05-09 11:17:00+08:00  16126.339844  16129.440430  16116.400391
# 2022-05-09 11:18:00+08:00  16126.589844  16128.959961  16119.919922
# 2022-05-09 11:19:00+08:00  16129.870117  16130.370117  16121.009766
# 2022-05-09 11:20:00+08:00  16126.049805  16128.440430  16118.129883
# 2022-05-09 11:21:35+08:00  16128.320312  16128.320312  16128.320312
#
#                                   Close     Adj Close  Volume
# ...
